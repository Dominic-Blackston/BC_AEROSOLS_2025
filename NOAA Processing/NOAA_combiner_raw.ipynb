# %%
import pandas as pd
import numpy as np
from igor2 import binarywave
import os
from pathlib import Path

# %%
def convert_igor_timestamp(timestamp_value):
    """
    Convert Igor Pro timestamp to pandas datetime
    Igor Pro uses seconds since 1904-01-01 00:00:00 UTC
    """
    igor_epoch = pd.Timestamp('1904-01-01 00:00:00', tz='UTC')
    datetime_result = igor_epoch + pd.Timedelta(seconds=timestamp_value)
    return datetime_result

def read_single_ibw(filepath):
    """Read a single IBW file and return as DataFrame"""
    try:
        # Load the IBW file
        data = binarywave.load(filepath)
        
        # Extract the wave data
        wave_data = data['wave']['wData']
        
        # Get wave name (filename without extension)
        wave_name = Path(filepath).stem
        
        # Create DataFrame
        if wave_data.ndim == 1:
            # 1D data
            df = pd.DataFrame({wave_name: wave_data})
        else:
            # Multi-dimensional data - flatten or handle as needed
            df = pd.DataFrame(wave_data)
            
        return df
        
    except Exception as e:
        print(f"Error reading {filepath}: {e}")
        return None

def process_instrument_folder(instrument_path, instrument_name):
    """
    Process all IBW files in an instrument folder
    Returns DataFrame with instrument-prefixed column names
    """
    print(f"Processing instrument: {instrument_name}")
    
    # Find all IBW files in the instrument folder
    ibw_files = list(Path(instrument_path).glob("*.ibw"))
    
    if not ibw_files:
        print(f"  No IBW files found in {instrument_path}")
        return None
    
    print(f"  Found {len(ibw_files)} IBW files")
    
    # Read and combine all IBW files for this instrument
    dataframes = []
    timestamp_column = None
    
    for filepath in ibw_files:
        try:
            # Load the IBW file
            data = binarywave.load(filepath)
            wave_data = data['wave']['wData']
            
            # Get column name from filename
            col_name = Path(filepath).stem
            
            # Handle different data shapes
            if wave_data.ndim == 1:
                df_temp = pd.DataFrame({col_name: wave_data})
            else:
                df_temp = pd.DataFrame({col_name: wave_data.flatten()})
            
            # Check if this is a timestamp column (contains "Time" in name)
            if 'time' in col_name.lower():
                timestamp_column = col_name
                print(f"    Found timestamp column: {col_name}")
            
            dataframes.append(df_temp)
            print(f"    Loaded: {col_name} ({len(df_temp)} rows)")
            
        except Exception as e:
            print(f"    Error reading {filepath}: {e}")
            continue
    
    if not dataframes:
        print(f"  No valid data found for {instrument_name}")
        return None
    
    # Combine all dataframes for this instrument
    try:
        instrument_df = pd.concat(dataframes, axis=1)
    except:
        instrument_df = pd.concat(dataframes, axis=1, join='outer')
    
    # Convert timestamps if we found a timestamp column
    if timestamp_column and timestamp_column in instrument_df.columns:
        print(f"    Converting timestamps from {timestamp_column}")
        instrument_df['UTC_datetime'] = instrument_df[timestamp_column].apply(convert_igor_timestamp)
        instrument_df['Date'] = instrument_df['UTC_datetime'].dt.date
        instrument_df['UTC'] = instrument_df['UTC_datetime'].dt.time
        
        # Drop the original timestamp column and UTC_datetime (keep Date and UTC for merging)
        instrument_df = instrument_df.drop(columns=[timestamp_column, 'UTC_datetime'])
    else:
        print(f"    Warning: No timestamp column found for {instrument_name}")
        return None
    
    # Rename columns with instrument prefix (except Date and UTC)
    columns_to_rename = [col for col in instrument_df.columns if col not in ['Date', 'UTC']]
    rename_dict = {col: f"{instrument_name}_{col}" for col in columns_to_rename}
    instrument_df = instrument_df.rename(columns=rename_dict)
    
    print(f"    Final columns: {instrument_df.columns.tolist()}")
    print(f"    Data shape: {instrument_df.shape}")
    
    return instrument_df

def process_campaign_data(campaign_path, output_path):
    """
    Process all instrument folders in a campaign
    Merge all data by Date and UTC columns
    """
    campaign_folder = Path(campaign_path)
    
    if not campaign_folder.exists():
        print(f"Campaign path does not exist: {campaign_path}")
        return None
    
    # Find all instrument folders (subdirectories)
    instrument_folders = [d for d in campaign_folder.iterdir() if d.is_dir()]
    
    if not instrument_folders:
        print(f"No instrument folders found in {campaign_path}")
        return None
    
    print(f"Found {len(instrument_folders)} instrument folders:")
    for folder in instrument_folders:
        print(f"  - {folder.name}")
    
    # Process each instrument folder
    all_instrument_data = []
    
    for instrument_folder in instrument_folders:
        instrument_name = instrument_folder.name
        instrument_df = process_instrument_folder(instrument_folder, instrument_name)
        
        if instrument_df is not None:
            all_instrument_data.append(instrument_df)
            print(f"✓ Successfully processed {instrument_name}")
        else:
            print(f"✗ Failed to process {instrument_name}")
        print("-" * 50)
    
    if not all_instrument_data:
        print("No valid instrument data found!")
        return None
    
    # Merge all instrument data by Date and UTC
    print("Merging all instrument data...")
    merged_df = all_instrument_data[0]
    
    for i, df in enumerate(all_instrument_data[1:], 1):
        print(f"  Merging instrument {i+1}/{len(all_instrument_data)}...")
        merged_df = pd.merge(merged_df, df, on=['Date', 'UTC'], how='outer')
    
    # Reorder columns to put Date and UTC at the front
    all_columns = merged_df.columns.tolist()
    other_columns = [col for col in all_columns if col not in ['Date', 'UTC']]
    ordered_columns = ['Date', 'UTC'] + other_columns
    merged_df = merged_df[ordered_columns]
    
    print(f"Final merged dataset shape: {merged_df.shape}")
    print(f"Final columns: {merged_df.columns.tolist()}")
    
    # Save to CSV
    output_file = os.path.join(output_path, "CALNEX_raw.csv")
    merged_df.to_csv(output_file, index=False)
    print(f"Saved to: {output_file}")
    
    return merged_df

# %%
# Main execution
if __name__ == "__main__":
    # Paths
    campaign_path = rf"C:\Users\haika\Desktop\May_Research\campaign_data\CALNEX"
    output_path = rf"C:\Users\haika\Desktop\May_Research\may_datasets\raw_campaigns"
    
    # Create output directory if it doesn't exist
    os.makedirs(output_path, exist_ok=True)
    
    # Process all campaign data
    print("="*60)
    print("PROCESSING CALNEX CAMPAIGN DATA")
    print("="*60)
    
    final_df = process_campaign_data(campaign_path, output_path)
    
    if final_df is not None:
        print("\n" + "="*60)
        print("PROCESSING COMPLETE!")
        print("="*60)
        print(f"Final dataset shape: {final_df.shape}")
        print(f"Date range: {final_df['Date'].min()} to {final_df['Date'].max()}")
        print(f"Number of instruments: {len([col for col in final_df.columns if '_' in col and col not in ['Date', 'UTC']])}")
        
        # Show sample of the data
        print("\nSample of merged data:")
        print(final_df.head())
        
        # Show data completeness
        print("\nData completeness by instrument:")
        instrument_cols = [col for col in final_df.columns if '_' in col and col not in ['Date', 'UTC']]
        for col in instrument_cols:
            completeness = (final_df[col].notna().sum() / len(final_df)) * 100
            print(f"  {col}: {completeness:.1f}%")
    else:
        print("Failed to process campaign data!")
# Out:
# ============================================================
# PROCESSING CALNEX CAMPAIGN DATA
# ============================================================
# Found 13 instrument folders:
#   - AircraftExt
#   - AircraftMet
#   - AircraftMis
#   - AircraftPos
#   - AMS
#   - CCN
#   - CloudProbes
#   - CRDExt
#   - LWC
#   - NAerosol
#   - PAS
#   - PSAP
#   - SP2
# Processing instrument: AircraftExt
#   Found 3 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: WindDir_smooth_all (462480 rows)
#     Loaded: WindSpd_smooth_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['AircraftExt_WindDir_smooth_all', 'AircraftExt_WindSpd_smooth_all', 'Date', 'UTC']
#     Data shape: (462480, 4)
# ✓ Successfully processed AircraftExt
# --------------------------------------------------
# Processing instrument: AircraftMet
#   Found 12 IBW files
#     Loaded: AmbTemp_all (462480 rows)
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: DewPtTempTDL_all (462480 rows)
#     Loaded: DewPtTemp_all (462480 rows)
#     Loaded: H2Omr_all (462480 rows)
#     Loaded: PotTemp_all (462480 rows)
#     Loaded: RelHumidity_all (462480 rows)
#     Loaded: SeaSfcTemp_all (462480 rows)
#     Loaded: StaticPrs_all (462480 rows)
#     Loaded: VertWindSpd_all (462480 rows)
#     Loaded: WindDir_all (462480 rows)
#     Loaded: WindSpd_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['AircraftMet_AmbTemp_all', 'AircraftMet_DewPtTempTDL_all', 'AircraftMet_DewPtTemp_all', 'AircraftMet_H2Omr_all', 'AircraftMet_PotTemp_all', 'AircraftMet_RelHumidity_all', 'AircraftMet_SeaSfcTemp_all', 'AircraftMet_StaticPrs_all', 'AircraftMet_VertWindSpd_all', 'AircraftMet_WindDir_all', 'AircraftMet_WindSpd_all', 'Date', 'UTC']
#     Data shape: (462480, 13)
# ✓ Successfully processed AircraftMet
# --------------------------------------------------
# Processing instrument: AircraftMis
#   Found 9 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: Attack_all (462480 rows)
#     Loaded: CabinPrs_all (462480 rows)
#     Loaded: GndSpd_all (462480 rows)
#     Loaded: Heading_all (462480 rows)
#     Loaded: Pitch_all (462480 rows)
#     Loaded: Roll_all (462480 rows)
#     Loaded: Slip_all (462480 rows)
#     Loaded: TrueAirSpd_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['AircraftMis_Attack_all', 'AircraftMis_CabinPrs_all', 'AircraftMis_GndSpd_all', 'AircraftMis_Heading_all', 'AircraftMis_Pitch_all', 'AircraftMis_Roll_all', 'AircraftMis_Slip_all', 'AircraftMis_TrueAirSpd_all', 'Date', 'UTC']
#     Data shape: (462480, 10)
# ✓ Successfully processed AircraftMis
# --------------------------------------------------
# Processing instrument: AircraftPos
#   Found 6 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: GpsAlt_all (462480 rows)
#     Loaded: GpsLat_all (462480 rows)
#     Loaded: GpsLon_all (462480 rows)
#     Loaded: PAlt_all (462480 rows)
#     Loaded: RAlt_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['AircraftPos_GpsAlt_all', 'AircraftPos_GpsLat_all', 'AircraftPos_GpsLon_all', 'AircraftPos_PAlt_all', 'AircraftPos_RAlt_all', 'Date', 'UTC']
#     Data shape: (462480, 7)
# ✓ Successfully processed AircraftPos
# --------------------------------------------------
# Processing instrument: AMS
#   Found 8 IBW files
#     Loaded: AMS_Chl_all (462480 rows)
#     Loaded: AMS_flag_HigherUncertainty_all (462480 rows)
#     Loaded: AMS_NH4_all (462480 rows)
#     Loaded: AMS_NO3_all (462480 rows)
#     Loaded: AMS_Org_all (462480 rows)
#     Loaded: AMS_SO4_all (462480 rows)
#     Loaded: AMS_Total_all (462480 rows)
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['AMS_AMS_Chl_all', 'AMS_AMS_flag_HigherUncertainty_all', 'AMS_AMS_NH4_all', 'AMS_AMS_NO3_all', 'AMS_AMS_Org_all', 'AMS_AMS_SO4_all', 'AMS_AMS_Total_all', 'Date', 'UTC']
#     Data shape: (462480, 9)
# ✓ Successfully processed AMS
# --------------------------------------------------
# Processing instrument: CCN
#   Found 11 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: CCN25_30_all (462480 rows)
#     Loaded: CCN30_35_all (462480 rows)
#     Loaded: CCN35_40_all (462480 rows)
#     Loaded: CCN40_45_all (462480 rows)
#     Loaded: CCN45_50_all (462480 rows)
#     Loaded: CCN50_55_all (462480 rows)
#     Loaded: CCN55_60_all (462480 rows)
#     Loaded: CCN60_65_all (462480 rows)
#     Loaded: CCN_Concentration_all (462480 rows)
#     Loaded: Supersaturation_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['CCN_CCN25_30_all', 'CCN_CCN30_35_all', 'CCN_CCN35_40_all', 'CCN_CCN40_45_all', 'CCN_CCN45_50_all', 'CCN_CCN50_55_all', 'CCN_CCN55_60_all', 'CCN_CCN60_65_all', 'CCN_CCN_Concentration_all', 'CCN_Supersaturation_all', 'Date', 'UTC']
#     Data shape: (462480, 12)
# ✓ Successfully processed CCN
# --------------------------------------------------
# Processing instrument: CloudProbes
#   Found 6 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: CAS_Num_all (462480 rows)
#     Loaded: CDP_Num_all (462480 rows)
#     Loaded: CIP_Num_all (462480 rows)
#     Loaded: Drizzle_Flag_all (462480 rows)
#     Loaded: Droplet_Flag_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['CloudProbes_CAS_Num_all', 'CloudProbes_CDP_Num_all', 'CloudProbes_CIP_Num_all', 'CloudProbes_Drizzle_Flag_all', 'CloudProbes_Droplet_Flag_all', 'Date', 'UTC']
#     Data shape: (462480, 7)
# ✓ Successfully processed CloudProbes
# --------------------------------------------------
# Processing instrument: CRDExt
#   Found 4 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: ext_angstrom_all (462480 rows)
#     Loaded: ext_dry_532nm_all (462480 rows)
#     Loaded: ext_gammaRH_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['CRDExt_ext_angstrom_all', 'CRDExt_ext_dry_532nm_all', 'CRDExt_ext_gammaRH_all', 'Date', 'UTC']
#     Data shape: (462480, 5)
# ✓ Successfully processed CRDExt
# --------------------------------------------------
# Processing instrument: LWC
#   Found 2 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: LWC_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['LWC_LWC_all', 'Date', 'UTC']
#     Data shape: (462480, 3)
# ✓ Successfully processed LWC
# --------------------------------------------------
# Processing instrument: NAerosol
#   Found 13 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: cloud_flag_all (462480 rows)
#     Loaded: ncoarse_all (462480 rows)
#     Loaded: ncoarse_smooth_all (462480 rows)
#     Loaded: nfine_all (462480 rows)
#     Loaded: scoarse_all (462480 rows)
#     Loaded: scoarse_smooth_all (462480 rows)
#     Loaded: sfine_all (462480 rows)
#     Loaded: vcoarse_all (462480 rows)
#     Loaded: vcoarse_smooth_all (462480 rows)
#     Loaded: vfine_all (462480 rows)
#     Loaded: vfine_ams_all (462480 rows)
#     Loaded: vfine_crdext_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['NAerosol_cloud_flag_all', 'NAerosol_ncoarse_all', 'NAerosol_ncoarse_smooth_all', 'NAerosol_nfine_all', 'NAerosol_scoarse_all', 'NAerosol_scoarse_smooth_all', 'NAerosol_sfine_all', 'NAerosol_vcoarse_all', 'NAerosol_vcoarse_smooth_all', 'NAerosol_vfine_all', 'NAerosol_vfine_ams_all', 'NAerosol_vfine_crdext_all', 'Date', 'UTC']
#     Data shape: (462480, 14)
# ✓ Successfully processed NAerosol
# --------------------------------------------------
# Processing instrument: PAS
#   Found 5 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: PAS_404_dry_STP_all (462480 rows)
#     Loaded: PAS_532_dry_STP_all (462480 rows)
#     Loaded: PAS_658_dry_STP_all (462480 rows)
#     Loaded: PAS_660_dry_STP_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['PAS_PAS_404_dry_STP_all', 'PAS_PAS_532_dry_STP_all', 'PAS_PAS_658_dry_STP_all', 'PAS_PAS_660_dry_STP_all', 'Date', 'UTC']
#     Data shape: (462480, 6)
# ✓ Successfully processed PAS
# --------------------------------------------------
# Processing instrument: PSAP
#   Found 4 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: PSAP_blue_sr_all (462480 rows)
#     Loaded: PSAP_green_sr_all (462480 rows)
#     Loaded: PSAP_red_sr_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['PSAP_PSAP_blue_sr_all', 'PSAP_PSAP_green_sr_all', 'PSAP_PSAP_red_sr_all', 'Date', 'UTC']
#     Data shape: (462480, 5)
# ✓ Successfully processed PSAP
# --------------------------------------------------
# Processing instrument: SP2
#   Found 3 IBW files
#     Found timestamp column: AOCTimewave_all
#     Loaded: AOCTimewave_all (462480 rows)
#     Loaded: BC_ng_kg_all (462480 rows)
#     Loaded: BC_ng_m3_all (462480 rows)
#     Converting timestamps from AOCTimewave_all
#     Final columns: ['SP2_BC_ng_kg_all', 'SP2_BC_ng_m3_all', 'Date', 'UTC']
#     Data shape: (462480, 4)
# ✓ Successfully processed SP2
# --------------------------------------------------
# Merging all instrument data...
#   Merging instrument 2/13...
#   Merging instrument 3/13...
#   Merging instrument 4/13...
#   Merging instrument 5/13...
#   Merging instrument 6/13...
#   Merging instrument 7/13...
#   Merging instrument 8/13...
#   Merging instrument 9/13...
#   Merging instrument 10/13...
#   Merging instrument 11/13...
#   Merging instrument 12/13...
#   Merging instrument 13/13...
# Final merged dataset shape: (462480, 75)
# Final columns: ['Date', 'UTC', 'AircraftExt_WindDir_smooth_all', 'AircraftExt_WindSpd_smooth_all', 'AircraftMet_AmbTemp_all', 'AircraftMet_DewPtTempTDL_all', 'AircraftMet_DewPtTemp_all', 'AircraftMet_H2Omr_all', 'AircraftMet_PotTemp_all', 'AircraftMet_RelHumidity_all', 'AircraftMet_SeaSfcTemp_all', 'AircraftMet_StaticPrs_all', 'AircraftMet_VertWindSpd_all', 'AircraftMet_WindDir_all', 'AircraftMet_WindSpd_all', 'AircraftMis_Attack_all', 'AircraftMis_CabinPrs_all', 'AircraftMis_GndSpd_all', 'AircraftMis_Heading_all', 'AircraftMis_Pitch_all', 'AircraftMis_Roll_all', 'AircraftMis_Slip_all', 'AircraftMis_TrueAirSpd_all', 'AircraftPos_GpsAlt_all', 'AircraftPos_GpsLat_all', 'AircraftPos_GpsLon_all', 'AircraftPos_PAlt_all', 'AircraftPos_RAlt_all', 'AMS_AMS_Chl_all', 'AMS_AMS_flag_HigherUncertainty_all', 'AMS_AMS_NH4_all', 'AMS_AMS_NO3_all', 'AMS_AMS_Org_all', 'AMS_AMS_SO4_all', 'AMS_AMS_Total_all', 'CCN_CCN25_30_all', 'CCN_CCN30_35_all', 'CCN_CCN35_40_all', 'CCN_CCN40_45_all', 'CCN_CCN45_50_all', 'CCN_CCN50_55_all', 'CCN_CCN55_60_all', 'CCN_CCN60_65_all', 'CCN_CCN_Concentration_all', 'CCN_Supersaturation_all', 'CloudProbes_CAS_Num_all', 'CloudProbes_CDP_Num_all', 'CloudProbes_CIP_Num_all', 'CloudProbes_Drizzle_Flag_all', 'CloudProbes_Droplet_Flag_all', 'CRDExt_ext_angstrom_all', 'CRDExt_ext_dry_532nm_all', 'CRDExt_ext_gammaRH_all', 'LWC_LWC_all', 'NAerosol_cloud_flag_all', 'NAerosol_ncoarse_all', 'NAerosol_ncoarse_smooth_all', 'NAerosol_nfine_all', 'NAerosol_scoarse_all', 'NAerosol_scoarse_smooth_all', 'NAerosol_sfine_all', 'NAerosol_vcoarse_all', 'NAerosol_vcoarse_smooth_all', 'NAerosol_vfine_all', 'NAerosol_vfine_ams_all', 'NAerosol_vfine_crdext_all', 'PAS_PAS_404_dry_STP_all', 'PAS_PAS_532_dry_STP_all', 'PAS_PAS_658_dry_STP_all', 'PAS_PAS_660_dry_STP_all', 'PSAP_PSAP_blue_sr_all', 'PSAP_PSAP_green_sr_all', 'PSAP_PSAP_red_sr_all', 'SP2_BC_ng_kg_all', 'SP2_BC_ng_m3_all']
# Saved to: C:\Users\haika\Desktop\May_Research\NOAA Processing\CALNEX_raw.csv
#
# ============================================================
# PROCESSING COMPLETE!
# ============================================================
# Final dataset shape: (462480, 75)
# Date range: 2010-04-30 to 2010-06-22
# Number of instruments: 73
#
# Sample of merged data:
#          Date       UTC  AircraftExt_WindDir_smooth_all  \
# 0  2010-04-30  17:14:00                             NaN
# 1  2010-04-30  17:14:01                             NaN
# 2  2010-04-30  17:14:02                             NaN
# 3  2010-04-30  17:14:03                             NaN
# 4  2010-04-30  17:14:04                             NaN
#
#    AircraftExt_WindSpd_smooth_all  AircraftMet_AmbTemp_all  \
# 0                             NaN                     8.01
# 1                             NaN                     7.98
# 2                             NaN                     7.93
# 3                             NaN                     7.86
# 4                             NaN                     7.84
#
#    AircraftMet_DewPtTempTDL_all  AircraftMet_DewPtTemp_all  \
# 0                         -8.77                     -11.87
# 1                         -8.74                     -11.77
# 2                         -8.85                     -11.97
# 3                         -9.03                     -11.45
# 4                         -8.67                     -11.83
#
#    AircraftMet_H2Omr_all  AircraftMet_PotTemp_all  \
# 0                   1.90               298.500000
# 1                   1.92               298.500000
# 2                   1.89               298.399994
# 3                   1.96               298.399994
# 4                   1.91               298.299988
#
#    AircraftMet_RelHumidity_all  ...  NAerosol_vfine_crdext_all  \
# 0                    22.700001  ...                        NaN
# 1                    22.980000  ...                        NaN
# 2                    22.660000  ...                        NaN
# 3                    23.700001  ...                        NaN
# 4                    23.110001  ...                        NaN
#
#    PAS_PAS_404_dry_STP_all  PAS_PAS_532_dry_STP_all  PAS_PAS_658_dry_STP_all  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    PAS_PAS_660_dry_STP_all  PSAP_PSAP_blue_sr_all  PSAP_PSAP_green_sr_all  \
# 0                      NaN                    NaN                     NaN
# 1                      NaN                    NaN                     NaN
# 2                      NaN                    NaN                     NaN
# 3                      NaN                    NaN                     NaN
# 4                      NaN                    NaN                     NaN
#
#    PSAP_PSAP_red_sr_all  SP2_BC_ng_kg_all  SP2_BC_ng_m3_all
# 0                   NaN              2.50              2.51
# 1                   NaN              4.15              4.16
# 2                   NaN              2.16              2.16
# 3                   NaN              3.30              3.32
# 4                   NaN              5.36              5.38
#
# [5 rows x 75 columns]
#
# Data completeness by instrument:
#   AircraftExt_WindDir_smooth_all: 95.2%
#   AircraftExt_WindSpd_smooth_all: 95.2%
#   AircraftMet_AmbTemp_all: 99.9%
#   AircraftMet_DewPtTempTDL_all: 99.9%
#   AircraftMet_DewPtTemp_all: 99.9%
#   AircraftMet_H2Omr_all: 99.9%
#   AircraftMet_PotTemp_all: 99.9%
#   AircraftMet_RelHumidity_all: 99.9%
#   AircraftMet_SeaSfcTemp_all: 99.9%
#   AircraftMet_StaticPrs_all: 99.9%
#   AircraftMet_VertWindSpd_all: 99.4%
#   AircraftMet_WindDir_all: 99.4%
#   AircraftMet_WindSpd_all: 99.4%
#   AircraftMis_Attack_all: 99.9%
#   AircraftMis_CabinPrs_all: 99.9%
#   AircraftMis_GndSpd_all: 99.9%
#   AircraftMis_Heading_all: 99.9%
#   AircraftMis_Pitch_all: 99.9%
#   AircraftMis_Roll_all: 99.9%
#   AircraftMis_Slip_all: 99.9%
#   AircraftMis_TrueAirSpd_all: 99.9%
#   AircraftPos_GpsAlt_all: 99.9%
#   AircraftPos_GpsLat_all: 99.9%
#   AircraftPos_GpsLon_all: 99.9%
#   AircraftPos_PAlt_all: 99.9%
#   AircraftPos_RAlt_all: 99.9%
#   AMS_AMS_Chl_all: 7.8%
#   AMS_AMS_flag_HigherUncertainty_all: 9.9%
#   AMS_AMS_NH4_all: 7.8%
#   AMS_AMS_NO3_all: 7.8%
#   AMS_AMS_Org_all: 7.8%
#   AMS_AMS_SO4_all: 7.8%
#   AMS_AMS_Total_all: 7.8%
#   CCN_CCN25_30_all: 1.0%
#   CCN_CCN30_35_all: 4.2%
#   CCN_CCN35_40_all: 4.9%
#   CCN_CCN40_45_all: 5.1%
#   CCN_CCN45_50_all: 5.3%
#   CCN_CCN50_55_all: 5.6%
#   CCN_CCN55_60_all: 5.9%
#   CCN_CCN60_65_all: 6.5%
#   CCN_CCN_Concentration_all: 39.4%
#   CCN_Supersaturation_all: 39.4%
#   CloudProbes_CAS_Num_all: 95.0%
#   CloudProbes_CDP_Num_all: 94.2%
#   CloudProbes_CIP_Num_all: 93.6%
#   CloudProbes_Drizzle_Flag_all: 2.4%
#   CloudProbes_Droplet_Flag_all: 1.9%
#   CRDExt_ext_angstrom_all: 5.8%
#   CRDExt_ext_dry_532nm_all: 78.5%
#   CRDExt_ext_gammaRH_all: 5.9%
#   LWC_LWC_all: 2.2%
#   NAerosol_cloud_flag_all: 100.0%
#   NAerosol_ncoarse_all: 65.4%
#   NAerosol_ncoarse_smooth_all: 66.5%
#   NAerosol_nfine_all: 83.9%
#   NAerosol_scoarse_all: 65.4%
#   NAerosol_scoarse_smooth_all: 66.5%
#   NAerosol_sfine_all: 76.8%
#   NAerosol_vcoarse_all: 65.4%
#   NAerosol_vcoarse_smooth_all: 66.5%
#   NAerosol_vfine_all: 76.8%
#   NAerosol_vfine_ams_all: 76.8%
#   NAerosol_vfine_crdext_all: 50.1%
#   PAS_PAS_404_dry_STP_all: 4.7%
#   PAS_PAS_532_dry_STP_all: 39.7%
#   PAS_PAS_658_dry_STP_all: 4.7%
#   PAS_PAS_660_dry_STP_all: 12.9%
#   PSAP_PSAP_blue_sr_all: 76.2%
#   PSAP_PSAP_green_sr_all: 79.0%
#   PSAP_PSAP_red_sr_all: 76.2%
#   SP2_BC_ng_kg_all: 92.4%
#   SP2_BC_ng_m3_all: 92.4%
